# %% [markdown]
# ## 데이터 준비

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.datasets import fetch_california_housing

# %%
california = fetch_california_housing()

df = pd.DataFrame(california.data, columns=california.feature_names)
df['Target'] = california.target
df.tail()
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  Target
# 20635    -121.09   0.781
# 20636    -121.21   0.771
# 20637    -121.22   0.923
# 20638    -121.32   0.847
# 20639    -121.24   0.894

# %%
sns.pairplot(df.sample(1000))
plt.show()

# %%
scaler = StandardScaler()
scaler.fit(df.values[:,:-1])
df.values[:,:-1] = scaler.transform(df.values[:,:-1])
sns.pairplot(df.sample(1000))
plt.show()

# %% [markdown]
# ## 학습 코드 구현

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
data = torch.from_numpy(df.values).float()
print(data.shape)
# Out:
# torch.Size([20640, 9])

# %%
x = data[:,:-1]
y = data[:,-1:]
print(x.shape, y.shape)
# Out:
# torch.Size([20640, 8]) torch.Size([20640, 1])

# %%
n_epochs = 4000
batch_size = 256
print_interval = 200
learning_rate = 1e-2

# %%
model = nn.Sequential(
    nn.Linear(x.size(-1), 6),
    nn.LeakyReLU(),
    nn.Linear(6,5),
    nn.LeakyReLU(),
    nn.Linear(5,4),
    nn.LeakyReLU(),
    nn.Linear(4,3),
    nn.LeakyReLU(),
    nn.Linear(3, y.size(-1)),
)
print(model)
# Out:
# Sequential(
#   (0): Linear(in_features=8, out_features=6, bias=True)
#   (1): LeakyReLU(negative_slope=0.01)
#   (2): Linear(in_features=6, out_features=5, bias=True)
#   (3): LeakyReLU(negative_slope=0.01)
#   (4): Linear(in_features=5, out_features=4, bias=True)
#   (5): LeakyReLU(negative_slope=0.01)
#   (6): Linear(in_features=4, out_features=3, bias=True)
#   (7): LeakyReLU(negative_slope=0.01)
#   (8): Linear(in_features=3, out_features=1, bias=True)
# )

# %%
optimizer = optim.SGD(model.parameters(), lr=learning_rate)

# %%
for i in range(n_epochs):
    # Shuffle the index to feed-forward.
    indices = torch.randperm(x.size(0))
    x_ = torch.index_select(x, dim=0, index=indices)
    y_ = torch.index_select(y, dim=0, index=indices)

    x_ = x_.split(batch_size, dim=0)
    y_ = y_.split(batch_size, dim=0)

    y_hat = []
    total_loss = 0

    for x_i, y_i in zip(x_, y_):
        y_hat_i = model(x_i)
        loss = F.mse_loss(y_hat_i, y_i)

        optimizer.zero_grad()
        loss.backward()

        optimizer.step()

        total_loss += float(loss)
        y_hat += [y_hat_i]

        total_loss = total_loss / len(x_)
        if (i + 1) % print_interval == 0:
            print('Epoch %d : Loss=%.4e' % (i + 1, total_loss))

y_hat = torch.cat(y_hat, dim=0)
y = torch.cat(y_, dim=0)
# Out:
# Epoch 200 : Loss=5.5535e-03
# Epoch 200 : Loss=3.1153e-03
# Epoch 200 : Loss=3.9024e-03
# Epoch 200 : Loss=3.8808e-03
# Epoch 200 : Loss=3.8792e-03
# Epoch 200 : Loss=3.6585e-03
# Epoch 200 : Loss=4.2953e-03
# Epoch 200 : Loss=5.1058e-03
# Epoch 200 : Loss=3.8874e-03
# Epoch 200 : Loss=4.3349e-03
# Epoch 200 : Loss=4.1994e-03
# Epoch 200 : Loss=4.5171e-03
# Epoch 200 : Loss=4.3598e-03
# Epoch 200 : Loss=3.7120e-03
# Epoch 200 : Loss=4.1697e-03
# Epoch 200 : Loss=3.2211e-03
# Epoch 200 : Loss=3.5047e-03
# Epoch 200 : Loss=3.8182e-03
# Epoch 200 : Loss=5.4091e-03
# Epoch 200 : Loss=4.2360e-03
# Epoch 200 : Loss=3.3126e-03
# Epoch 200 : Loss=3.1820e-03
# Epoch 200 : Loss=4.3856e-03
# Epoch 200 : Loss=3.3997e-03
# Epoch 200 : Loss=3.3839e-03
# Epoch 200 : Loss=4.6472e-03
# Epoch 200 : Loss=3.3091e-03
# Epoch 200 : Loss=4.0652e-03
# Epoch 200 : Loss=3.9074e-03
# Epoch 200 : Loss=3.6142e-03
# Epoch 200 : Loss=3.2326e-03
# Epoch 200 : Loss=3.9880e-03
# Epoch 200 : Loss=3.3012e-03
# Epoch 200 : Loss=3.6707e-03
# Epoch 200 : Loss=3.1371e-03
# Epoch 200 : Loss=4.2806e-03
# Epoch 200 : Loss=3.6925e-03
# Epoch 200 : Loss=4.8863e-03
# Epoch 200 : Loss=3.5646e-03
# Epoch 200 : Loss=3.9673e-03
# Epoch 200 : Loss=3.6140e-03
# Epoch 200 : Loss=4.0027e-03
# Epoch 200 : Loss=3.7625e-03
# Epoch 200 : Loss=3.0317e-03
# Epoch 200 : Loss=4.3356e-03
# Epoch 200 : Loss=4.5277e-03
# Epoch 200 : Loss=4.2802e-03
# Epoch 200 : Loss=4.3410e-03
# Epoch 200 : Loss=4.3362e-03
# Epoch 200 : Loss=2.9682e-03
# Epoch 200 : Loss=3.5569e-03
# Epoch 200 : Loss=3.9499e-03
# Epoch 200 : Loss=2.6139e-03
# Epoch 200 : Loss=3.8096e-03
# Epoch 200 : Loss=3.9982e-03
# Epoch 200 : Loss=4.4962e-03
# Epoch 200 : Loss=3.9948e-03
# Epoch 200 : Loss=3.4728e-03
# Epoch 200 : Loss=5.3741e-03
# Epoch 200 : Loss=4.3099e-03
# Epoch 200 : Loss=4.5987e-03
# Epoch 200 : Loss=5.4506e-03
# Epoch 200 : Loss=3.9651e-03
# Epoch 200 : Loss=4.4183e-03
# Epoch 200 : Loss=4.9502e-03
# Epoch 200 : Loss=5.0212e-03
# Epoch 200 : Loss=3.2791e-03
# Epoch 200 : Loss=4.0918e-03
# Epoch 200 : Loss=3.8632e-03
# Epoch 200 : Loss=4.1741e-03
# Epoch 200 : Loss=4.7339e-03
# Epoch 200 : Loss=4.1651e-03
# Epoch 200 : Loss=4.5717e-03
# Epoch 200 : Loss=5.3032e-03
# Epoch 200 : Loss=4.9098e-03
# Epoch 200 : Loss=4.7913e-03
# Epoch 200 : Loss=3.9016e-03
# Epoch 200 : Loss=3.6354e-03
# Epoch 200 : Loss=3.7908e-03
# Epoch 200 : Loss=3.5988e-03
# Epoch 200 : Loss=3.5441e-03
# Epoch 400 : Loss=3.4408e-03
# Epoch 400 : Loss=5.4374e-03
# Epoch 400 : Loss=4.0166e-03
# Epoch 400 : Loss=4.1923e-03
# Epoch 400 : Loss=2.7385e-03
# Epoch 400 : Loss=4.7355e-03
# Epoch 400 : Loss=3.7619e-03
# Epoch 400 : Loss=3.9481e-03
# Epoch 400 : Loss=5.2192e-03
# Epoch 400 : Loss=4.3114e-03
# Epoch 400 : Loss=3.0662e-03
# Epoch 400 : Loss=4.8599e-03
# Epoch 400 : Loss=3.3031e-03
# Epoch 400 : Loss=3.9788e-03
# Epoch 400 : Loss=3.3624e-03
# Epoch 400 : Loss=3.9058e-03
# Epoch 400 : Loss=3.2575e-03
# Epoch 400 : Loss=3.5673e-03
# Epoch 400 : Loss=4.4538e-03
# Epoch 400 : Loss=3.7612e-03
# Epoch 400 : Loss=3.7259e-03
# Epoch 400 : Loss=3.9282e-03
# Epoch 400 : Loss=4.1985e-03
# Epoch 400 : Loss=5.5989e-03
# Epoch 400 : Loss=3.6435e-03
# Epoch 400 : Loss=3.6589e-03
# Epoch 400 : Loss=3.6725e-03
# Epoch 400 : Loss=4.2718e-03
# Epoch 400 : Loss=3.9049e-03
# Epoch 400 : Loss=3.2417e-03
# Epoch 400 : Loss=4.0446e-03
# Epoch 400 : Loss=4.3732e-03
# Epoch 400 : Loss=4.1498e-03
# Epoch 400 : Loss=3.5025e-03
# Epoch 400 : Loss=4.0897e-03
# Epoch 400 : Loss=3.5814e-03
# Epoch 400 : Loss=2.8640e-03
# Epoch 400 : Loss=3.3433e-03
# Epoch 400 : Loss=4.1301e-03
# Epoch 400 : Loss=3.6904e-03
# Epoch 400 : Loss=2.8353e-03
# Epoch 400 : Loss=5.0153e-03
# Epoch 400 : Loss=4.1425e-03
# Epoch 400 : Loss=4.2391e-03
# Epoch 400 : Loss=3.6629e-03
# Epoch 400 : Loss=4.4871e-03
# Epoch 400 : Loss=3.6673e-03
# Epoch 400 : Loss=3.2898e-03
# Epoch 400 : Loss=3.3730e-03
# Epoch 400 : Loss=3.7904e-03
# Epoch 400 : Loss=4.3389e-03
# Epoch 400 : Loss=4.0081e-03
# Epoch 400 : Loss=4.4479e-03
# Epoch 400 : Loss=3.6560e-03
# Epoch 400 : Loss=4.0443e-03
# Epoch 400 : Loss=4.0809e-03
# Epoch 400 : Loss=3.7910e-03
# Epoch 400 : Loss=4.3075e-03
# Epoch 400 : Loss=3.9558e-03
# Epoch 400 : Loss=4.7605e-03
# Epoch 400 : Loss=3.5737e-03
# Epoch 400 : Loss=3.3092e-03
# Epoch 400 : Loss=4.2051e-03
# Epoch 400 : Loss=4.8330e-03
# Epoch 400 : Loss=3.3600e-03
# Epoch 400 : Loss=3.6259e-03
# Epoch 400 : Loss=3.9794e-03
# Epoch 400 : Loss=4.1012e-03
# Epoch 400 : Loss=3.5505e-03
# Epoch 400 : Loss=2.9240e-03
# Epoch 400 : Loss=4.4209e-03
# Epoch 400 : Loss=4.0870e-03
# Epoch 400 : Loss=3.5170e-03
# Epoch 400 : Loss=3.9069e-03
# Epoch 400 : Loss=3.2892e-03
# Epoch 400 : Loss=4.6174e-03
# Epoch 400 : Loss=4.2275e-03
# Epoch 400 : Loss=5.1018e-03
# Epoch 400 : Loss=3.7249e-03
# Epoch 400 : Loss=3.0494e-03
# Epoch 400 : Loss=3.8427e-03
# Epoch 600 : Loss=4.9727e-03
# Epoch 600 : Loss=4.0051e-03
# Epoch 600 : Loss=3.5544e-03
# Epoch 600 : Loss=3.5813e-03
# Epoch 600 : Loss=4.2865e-03
# Epoch 600 : Loss=2.7779e-03
# Epoch 600 : Loss=2.7921e-03
# Epoch 600 : Loss=3.7832e-03
# Epoch 600 : Loss=3.8181e-03
# Epoch 600 : Loss=3.9535e-03
# Epoch 600 : Loss=4.6799e-03
# Epoch 600 : Loss=4.1964e-03
# Epoch 600 : Loss=4.8148e-03
# Epoch 600 : Loss=3.0365e-03
# Epoch 600 : Loss=4.3502e-03
# Epoch 600 : Loss=4.1795e-03
# Epoch 600 : Loss=3.9719e-03
# Epoch 600 : Loss=3.4706e-03
# Epoch 600 : Loss=3.9737e-03
# Epoch 600 : Loss=4.6009e-03
# Epoch 600 : Loss=4.3707e-03
# Epoch 600 : Loss=3.8545e-03
# Epoch 600 : Loss=3.7380e-03
# Epoch 600 : Loss=3.4308e-03
# Epoch 600 : Loss=4.2101e-03
# Epoch 600 : Loss=3.4743e-03
# Epoch 600 : Loss=4.5128e-03
# Epoch 600 : Loss=3.7516e-03
# Epoch 600 : Loss=3.7700e-03
# Epoch 600 : Loss=4.6924e-03
# Epoch 600 : Loss=5.3047e-03
# Epoch 600 : Loss=4.9042e-03
# Epoch 600 : Loss=3.5759e-03
# Epoch 600 : Loss=4.1254e-03
# Epoch 600 : Loss=3.3160e-03
# Epoch 600 : Loss=3.7054e-03
# Epoch 600 : Loss=3.9550e-03
# Epoch 600 : Loss=3.2658e-03
# Epoch 600 : Loss=5.5445e-03
# Epoch 600 : Loss=3.1098e-03
# Epoch 600 : Loss=3.2269e-03
# Epoch 600 : Loss=4.0545e-03
# Epoch 600 : Loss=3.8539e-03
# Epoch 600 : Loss=3.6011e-03
# Epoch 600 : Loss=3.7740e-03
# Epoch 600 : Loss=2.6480e-03
# Epoch 600 : Loss=4.6377e-03
# Epoch 600 : Loss=3.2296e-03
# Epoch 600 : Loss=3.5418e-03
# Epoch 600 : Loss=2.6565e-03
# Epoch 600 : Loss=4.2075e-03
# Epoch 600 : Loss=4.2080e-03
# Epoch 600 : Loss=4.3043e-03
# Epoch 600 : Loss=3.9101e-03
# Epoch 600 : Loss=3.5380e-03
# Epoch 600 : Loss=4.7475e-03
# Epoch 600 : Loss=3.5528e-03
# Epoch 600 : Loss=4.1454e-03
# Epoch 600 : Loss=4.3557e-03
# Epoch 600 : Loss=4.0411e-03
# Epoch 600 : Loss=2.5567e-03
# Epoch 600 : Loss=3.8580e-03
# Epoch 600 : Loss=3.5101e-03
# Epoch 600 : Loss=3.9376e-03
# Epoch 600 : Loss=3.9278e-03
# Epoch 600 : Loss=3.8159e-03
# Epoch 600 : Loss=3.4650e-03
# Epoch 600 : Loss=3.9547e-03
# Epoch 600 : Loss=3.2131e-03
# Epoch 600 : Loss=4.3846e-03
# Epoch 600 : Loss=3.8401e-03
# Epoch 600 : Loss=4.0410e-03
# Epoch 600 : Loss=4.8758e-03
# Epoch 600 : Loss=4.3477e-03
# Epoch 600 : Loss=3.2835e-03
# Epoch 600 : Loss=4.1041e-03
# Epoch 600 : Loss=3.6063e-03
# Epoch 600 : Loss=4.0618e-03
# Epoch 600 : Loss=3.2631e-03
# Epoch 600 : Loss=4.0543e-03
# Epoch 600 : Loss=4.4332e-03
# Epoch 800 : Loss=3.3586e-03
# Epoch 800 : Loss=3.5386e-03
# Epoch 800 : Loss=3.0467e-03
# Epoch 800 : Loss=5.0917e-03
# Epoch 800 : Loss=3.9559e-03
# Epoch 800 : Loss=2.9214e-03
# Epoch 800 : Loss=4.0503e-03
# Epoch 800 : Loss=4.0077e-03
# Epoch 800 : Loss=3.3043e-03
# Epoch 800 : Loss=3.2007e-03
# Epoch 800 : Loss=2.9108e-03
# Epoch 800 : Loss=3.7985e-03
# Epoch 800 : Loss=3.8367e-03
# Epoch 800 : Loss=4.8064e-03
# Epoch 800 : Loss=4.1878e-03
# Epoch 800 : Loss=3.2218e-03
# Epoch 800 : Loss=3.8646e-03
# Epoch 800 : Loss=4.6729e-03
# Epoch 800 : Loss=3.6783e-03
# Epoch 800 : Loss=3.8124e-03
# Epoch 800 : Loss=3.9780e-03
# Epoch 800 : Loss=3.3708e-03
# Epoch 800 : Loss=4.8049e-03
# Epoch 800 : Loss=4.7685e-03
# Epoch 800 : Loss=3.3820e-03
# Epoch 800 : Loss=3.4154e-03
# Epoch 800 : Loss=5.2475e-03
# Epoch 800 : Loss=3.6788e-03
# Epoch 800 : Loss=4.2868e-03
# Epoch 800 : Loss=3.5853e-03
# Epoch 800 : Loss=3.5930e-03
# Epoch 800 : Loss=3.9593e-03
# Epoch 800 : Loss=3.8380e-03
# Epoch 800 : Loss=4.2689e-03
# Epoch 800 : Loss=4.0290e-03
# Epoch 800 : Loss=2.8747e-03
# Epoch 800 : Loss=5.7345e-03
# Epoch 800 : Loss=3.1611e-03
# Epoch 800 : Loss=3.7451e-03
# Epoch 800 : Loss=4.7902e-03
# Epoch 800 : Loss=3.8873e-03
# Epoch 800 : Loss=4.2510e-03
# Epoch 800 : Loss=4.0974e-03
# Epoch 800 : Loss=3.9131e-03
# Epoch 800 : Loss=3.4885e-03
# Epoch 800 : Loss=3.5307e-03
# Epoch 800 : Loss=5.1766e-03
# Epoch 800 : Loss=4.4804e-03
# Epoch 800 : Loss=4.2384e-03
# Epoch 800 : Loss=4.5129e-03
# Epoch 800 : Loss=4.2984e-03
# Epoch 800 : Loss=2.9078e-03
# Epoch 800 : Loss=3.8753e-03
# Epoch 800 : Loss=4.7354e-03
# Epoch 800 : Loss=4.0074e-03
# Epoch 800 : Loss=3.2076e-03
# Epoch 800 : Loss=3.6795e-03
# Epoch 800 : Loss=2.9531e-03
# Epoch 800 : Loss=3.2646e-03
# Epoch 800 : Loss=3.5715e-03
# Epoch 800 : Loss=3.8337e-03
# Epoch 800 : Loss=3.9331e-03
# Epoch 800 : Loss=3.3154e-03
# Epoch 800 : Loss=3.5101e-03
# Epoch 800 : Loss=3.2166e-03
# Epoch 800 : Loss=3.6891e-03
# Epoch 800 : Loss=3.4124e-03
# Epoch 800 : Loss=3.0187e-03
# Epoch 800 : Loss=3.4239e-03
# Epoch 800 : Loss=3.7246e-03
# Epoch 800 : Loss=3.5202e-03
# Epoch 800 : Loss=3.9329e-03
# Epoch 800 : Loss=3.7699e-03
# Epoch 800 : Loss=3.3945e-03
# Epoch 800 : Loss=3.7319e-03
# Epoch 800 : Loss=2.8001e-03
# Epoch 800 : Loss=3.9492e-03
# Epoch 800 : Loss=3.4865e-03
# Epoch 800 : Loss=3.4560e-03
# Epoch 800 : Loss=5.2511e-03
# Epoch 800 : Loss=3.5705e-03
# Epoch 1000 : Loss=3.3626e-03
# Epoch 1000 : Loss=4.0900e-03
# Epoch 1000 : Loss=4.5466e-03
# Epoch 1000 : Loss=4.2931e-03
# Epoch 1000 : Loss=5.0671e-03
# Epoch 1000 : Loss=3.8014e-03
# Epoch 1000 : Loss=4.1698e-03
# Epoch 1000 : Loss=3.4332e-03
# Epoch 1000 : Loss=4.3220e-03
# Epoch 1000 : Loss=4.4341e-03
# Epoch 1000 : Loss=3.4696e-03
# Epoch 1000 : Loss=3.8691e-03
# Epoch 1000 : Loss=4.1293e-03
# Epoch 1000 : Loss=3.9292e-03
# Epoch 1000 : Loss=3.2614e-03
# Epoch 1000 : Loss=3.3567e-03
# Epoch 1000 : Loss=3.7797e-03
# Epoch 1000 : Loss=3.3589e-03
# Epoch 1000 : Loss=2.7760e-03
# Epoch 1000 : Loss=3.3327e-03
# Epoch 1000 : Loss=2.8092e-03
# Epoch 1000 : Loss=3.5132e-03
# Epoch 1000 : Loss=4.7523e-03
# Epoch 1000 : Loss=4.3390e-03
# Epoch 1000 : Loss=3.7186e-03
# Epoch 1000 : Loss=3.6253e-03
# Epoch 1000 : Loss=4.3094e-03
# Epoch 1000 : Loss=3.5481e-03
# Epoch 1000 : Loss=3.9815e-03
# Epoch 1000 : Loss=3.0840e-03
# Epoch 1000 : Loss=3.5261e-03
# Epoch 1000 : Loss=4.3032e-03
# Epoch 1000 : Loss=2.9373e-03
# Epoch 1000 : Loss=3.1982e-03
# Epoch 1000 : Loss=2.9826e-03
# Epoch 1000 : Loss=3.5923e-03
# Epoch 1000 : Loss=4.9735e-03
# Epoch 1000 : Loss=3.9113e-03
# Epoch 1000 : Loss=3.5176e-03
# Epoch 1000 : Loss=3.4887e-03
# Epoch 1000 : Loss=3.9544e-03
# Epoch 1000 : Loss=3.1611e-03
# Epoch 1000 : Loss=2.7964e-03
# Epoch 1000 : Loss=4.1384e-03
# Epoch 1000 : Loss=2.7328e-03
# Epoch 1000 : Loss=3.9607e-03
# Epoch 1000 : Loss=3.0866e-03
# Epoch 1000 : Loss=3.3764e-03
# Epoch 1000 : Loss=5.1194e-03
# Epoch 1000 : Loss=3.7700e-03
# Epoch 1000 : Loss=3.2315e-03
# Epoch 1000 : Loss=3.3834e-03
# Epoch 1000 : Loss=2.6342e-03
# Epoch 1000 : Loss=3.1522e-03
# Epoch 1000 : Loss=3.9849e-03
# Epoch 1000 : Loss=4.0941e-03
# Epoch 1000 : Loss=3.1634e-03
# Epoch 1000 : Loss=4.1415e-03
# Epoch 1000 : Loss=3.9230e-03
# Epoch 1000 : Loss=3.9724e-03
# Epoch 1000 : Loss=4.5545e-03
# Epoch 1000 : Loss=3.0115e-03
# Epoch 1000 : Loss=4.0012e-03
# Epoch 1000 : Loss=3.5491e-03
# Epoch 1000 : Loss=2.4808e-03
# Epoch 1000 : Loss=3.1496e-03
# Epoch 1000 : Loss=3.6499e-03
# Epoch 1000 : Loss=3.8698e-03
# Epoch 1000 : Loss=4.4201e-03
# Epoch 1000 : Loss=4.0778e-03
# Epoch 1000 : Loss=3.9203e-03
# Epoch 1000 : Loss=3.2014e-03
# Epoch 1000 : Loss=2.7739e-03
# Epoch 1000 : Loss=3.1049e-03
# Epoch 1000 : Loss=3.3563e-03
# Epoch 1000 : Loss=3.2536e-03
# Epoch 1000 : Loss=3.9613e-03
# Epoch 1000 : Loss=3.7680e-03
# Epoch 1000 : Loss=4.0952e-03
# Epoch 1000 : Loss=4.5009e-03
# Epoch 1000 : Loss=3.0253e-03
# Epoch 1200 : Loss=4.0281e-03
# Epoch 1200 : Loss=3.7345e-03
# Epoch 1200 : Loss=2.9525e-03
# Epoch 1200 : Loss=4.5053e-03
# Epoch 1200 : Loss=3.1594e-03
# Epoch 1200 : Loss=3.2738e-03
# Epoch 1200 : Loss=3.0831e-03
# Epoch 1200 : Loss=3.8629e-03
# Epoch 1200 : Loss=4.1152e-03
# Epoch 1200 : Loss=4.0480e-03
# Epoch 1200 : Loss=3.3073e-03
# Epoch 1200 : Loss=3.1427e-03
# Epoch 1200 : Loss=3.4794e-03
# Epoch 1200 : Loss=3.4441e-03
# Epoch 1200 : Loss=3.9680e-03
# Epoch 1200 : Loss=5.4147e-03
# Epoch 1200 : Loss=3.3664e-03
# Epoch 1200 : Loss=4.0833e-03
# Epoch 1200 : Loss=3.9623e-03
# Epoch 1200 : Loss=2.8415e-03
# Epoch 1200 : Loss=3.2914e-03
# Epoch 1200 : Loss=3.0526e-03
# Epoch 1200 : Loss=2.7448e-03
# Epoch 1200 : Loss=4.1848e-03
# Epoch 1200 : Loss=3.5140e-03
# Epoch 1200 : Loss=2.5157e-03
# Epoch 1200 : Loss=4.8329e-03
# Epoch 1200 : Loss=4.5249e-03
# Epoch 1200 : Loss=4.7961e-03
# Epoch 1200 : Loss=3.5918e-03
# Epoch 1200 : Loss=3.4403e-03
# Epoch 1200 : Loss=3.7328e-03
# Epoch 1200 : Loss=3.3619e-03
# Epoch 1200 : Loss=3.4796e-03
# Epoch 1200 : Loss=4.3897e-03
# Epoch 1200 : Loss=5.0648e-03
# Epoch 1200 : Loss=3.4860e-03
# Epoch 1200 : Loss=4.1897e-03
# Epoch 1200 : Loss=3.6645e-03
# Epoch 1200 : Loss=3.3937e-03
# Epoch 1200 : Loss=2.9893e-03
# Epoch 1200 : Loss=4.8218e-03
# Epoch 1200 : Loss=4.4460e-03
# Epoch 1200 : Loss=3.7708e-03
# Epoch 1200 : Loss=3.6224e-03
# Epoch 1200 : Loss=3.5268e-03
# Epoch 1200 : Loss=2.3250e-03
# Epoch 1200 : Loss=3.3889e-03
# Epoch 1200 : Loss=3.3574e-03
# Epoch 1200 : Loss=3.2515e-03
# Epoch 1200 : Loss=3.6077e-03
# Epoch 1200 : Loss=3.4502e-03
# Epoch 1200 : Loss=3.8231e-03
# Epoch 1200 : Loss=3.6539e-03
# Epoch 1200 : Loss=3.0269e-03
# Epoch 1200 : Loss=3.8792e-03
# Epoch 1200 : Loss=4.6732e-03
# Epoch 1200 : Loss=3.5962e-03
# Epoch 1200 : Loss=3.1387e-03
# Epoch 1200 : Loss=3.3329e-03
# Epoch 1200 : Loss=3.5256e-03
# Epoch 1200 : Loss=3.3715e-03
# Epoch 1200 : Loss=3.7840e-03
# Epoch 1200 : Loss=2.9127e-03
# Epoch 1200 : Loss=2.7515e-03
# Epoch 1200 : Loss=2.0809e-03
# Epoch 1200 : Loss=3.2904e-03
# Epoch 1200 : Loss=2.8955e-03
# Epoch 1200 : Loss=3.5445e-03
# Epoch 1200 : Loss=3.6701e-03
# Epoch 1200 : Loss=3.2239e-03
# Epoch 1200 : Loss=4.2947e-03
# Epoch 1200 : Loss=3.7743e-03
# Epoch 1200 : Loss=3.6790e-03
# Epoch 1200 : Loss=3.0860e-03
# Epoch 1200 : Loss=4.0467e-03
# Epoch 1200 : Loss=3.5903e-03
# Epoch 1200 : Loss=4.9429e-03
# Epoch 1200 : Loss=3.4103e-03
# Epoch 1200 : Loss=3.7937e-03
# Epoch 1200 : Loss=3.5862e-03
# Epoch 1400 : Loss=3.8067e-03
# Epoch 1400 : Loss=4.1849e-03
# Epoch 1400 : Loss=4.3063e-03
# Epoch 1400 : Loss=3.1389e-03
# Epoch 1400 : Loss=2.9898e-03
# Epoch 1400 : Loss=3.0644e-03
# Epoch 1400 : Loss=3.1214e-03
# Epoch 1400 : Loss=3.4963e-03
# Epoch 1400 : Loss=3.5402e-03
# Epoch 1400 : Loss=3.0544e-03
# Epoch 1400 : Loss=3.3425e-03
# Epoch 1400 : Loss=2.6516e-03
# Epoch 1400 : Loss=3.6418e-03
# Epoch 1400 : Loss=3.2629e-03
# Epoch 1400 : Loss=2.8788e-03
# Epoch 1400 : Loss=4.0253e-03
# Epoch 1400 : Loss=3.4208e-03
# Epoch 1400 : Loss=4.2228e-03
# Epoch 1400 : Loss=4.7291e-03
# Epoch 1400 : Loss=3.4748e-03
# Epoch 1400 : Loss=4.3356e-03
# Epoch 1400 : Loss=3.8692e-03
# Epoch 1400 : Loss=3.5649e-03
# Epoch 1400 : Loss=3.7768e-03
# Epoch 1400 : Loss=3.8582e-03
# Epoch 1400 : Loss=3.0977e-03
# Epoch 1400 : Loss=3.5252e-03
# Epoch 1400 : Loss=3.0498e-03
# Epoch 1400 : Loss=3.7364e-03
# Epoch 1400 : Loss=2.7143e-03
# Epoch 1400 : Loss=4.1210e-03
# Epoch 1400 : Loss=3.5660e-03
# Epoch 1400 : Loss=4.5348e-03
# Epoch 1400 : Loss=4.1164e-03
# Epoch 1400 : Loss=5.7297e-03
# Epoch 1400 : Loss=3.4857e-03
# Epoch 1400 : Loss=2.6018e-03
# Epoch 1400 : Loss=4.1439e-03
# Epoch 1400 : Loss=3.3865e-03
# Epoch 1400 : Loss=2.7357e-03
# Epoch 1400 : Loss=4.1069e-03
# Epoch 1400 : Loss=4.4146e-03
# Epoch 1400 : Loss=4.8092e-03
# Epoch 1400 : Loss=3.0213e-03
# Epoch 1400 : Loss=4.1916e-03
# Epoch 1400 : Loss=3.8405e-03
# Epoch 1400 : Loss=3.6066e-03
# Epoch 1400 : Loss=3.6323e-03
# Epoch 1400 : Loss=2.8384e-03
# Epoch 1400 : Loss=3.4210e-03
# Epoch 1400 : Loss=4.2668e-03
# Epoch 1400 : Loss=2.8482e-03
# Epoch 1400 : Loss=2.8910e-03
# Epoch 1400 : Loss=3.2327e-03
# Epoch 1400 : Loss=3.0212e-03
# Epoch 1400 : Loss=2.9730e-03
# Epoch 1400 : Loss=2.3750e-03
# Epoch 1400 : Loss=3.2395e-03
# Epoch 1400 : Loss=3.5515e-03
# Epoch 1400 : Loss=3.7604e-03
# Epoch 1400 : Loss=4.3004e-03
# Epoch 1400 : Loss=2.3901e-03
# Epoch 1400 : Loss=2.9949e-03
# Epoch 1400 : Loss=3.4897e-03
# Epoch 1400 : Loss=2.9958e-03
# Epoch 1400 : Loss=4.1425e-03
# Epoch 1400 : Loss=3.2833e-03
# Epoch 1400 : Loss=4.0400e-03
# Epoch 1400 : Loss=3.0516e-03
# Epoch 1400 : Loss=3.9185e-03
# Epoch 1400 : Loss=4.5415e-03
# Epoch 1400 : Loss=3.0629e-03
# Epoch 1400 : Loss=2.9446e-03
# Epoch 1400 : Loss=3.6300e-03
# Epoch 1400 : Loss=3.5779e-03
# Epoch 1400 : Loss=3.9011e-03
# Epoch 1400 : Loss=3.3520e-03
# Epoch 1400 : Loss=3.5565e-03
# Epoch 1400 : Loss=3.2033e-03
# Epoch 1400 : Loss=2.9224e-03
# Epoch 1400 : Loss=2.3265e-03
# Epoch 1600 : Loss=3.9733e-03
# Epoch 1600 : Loss=3.2416e-03
# Epoch 1600 : Loss=4.6059e-03
# Epoch 1600 : Loss=4.8854e-03
# Epoch 1600 : Loss=3.3876e-03
# Epoch 1600 : Loss=3.8115e-03
# Epoch 1600 : Loss=5.2450e-03
# Epoch 1600 : Loss=5.0956e-03
# Epoch 1600 : Loss=3.4563e-03
# Epoch 1600 : Loss=3.8610e-03
# Epoch 1600 : Loss=3.0286e-03
# Epoch 1600 : Loss=4.7028e-03
# Epoch 1600 : Loss=3.8680e-03
# Epoch 1600 : Loss=2.0203e-03
# Epoch 1600 : Loss=3.9731e-03
# Epoch 1600 : Loss=3.6218e-03
# Epoch 1600 : Loss=3.5199e-03
# Epoch 1600 : Loss=2.1978e-03
# Epoch 1600 : Loss=2.4684e-03
# Epoch 1600 : Loss=3.6138e-03
# Epoch 1600 : Loss=5.2506e-03
# Epoch 1600 : Loss=2.9551e-03
# Epoch 1600 : Loss=3.4361e-03
# Epoch 1600 : Loss=3.0058e-03
# Epoch 1600 : Loss=2.6518e-03
# Epoch 1600 : Loss=3.9088e-03
# Epoch 1600 : Loss=3.2267e-03
# Epoch 1600 : Loss=4.3697e-03
# Epoch 1600 : Loss=4.1804e-03
# Epoch 1600 : Loss=3.6479e-03
# Epoch 1600 : Loss=4.1014e-03
# Epoch 1600 : Loss=3.3960e-03
# Epoch 1600 : Loss=3.5698e-03
# Epoch 1600 : Loss=3.5939e-03
# Epoch 1600 : Loss=3.6236e-03
# Epoch 1600 : Loss=3.9431e-03
# Epoch 1600 : Loss=2.5646e-03
# Epoch 1600 : Loss=3.1492e-03
# Epoch 1600 : Loss=2.8351e-03
# Epoch 1600 : Loss=4.3204e-03
# Epoch 1600 : Loss=3.9330e-03
# Epoch 1600 : Loss=4.0993e-03
# Epoch 1600 : Loss=3.3577e-03
# Epoch 1600 : Loss=3.4253e-03
# Epoch 1600 : Loss=3.8737e-03
# Epoch 1600 : Loss=3.9956e-03
# Epoch 1600 : Loss=3.1162e-03
# Epoch 1600 : Loss=2.4317e-03
# Epoch 1600 : Loss=2.7064e-03
# Epoch 1600 : Loss=3.6724e-03
# Epoch 1600 : Loss=2.8577e-03
# Epoch 1600 : Loss=2.8222e-03
# Epoch 1600 : Loss=3.7509e-03
# Epoch 1600 : Loss=4.6104e-03
# Epoch 1600 : Loss=3.4662e-03
# Epoch 1600 : Loss=3.4144e-03
# Epoch 1600 : Loss=2.4157e-03
# Epoch 1600 : Loss=3.5352e-03
# Epoch 1600 : Loss=2.8765e-03
# Epoch 1600 : Loss=3.1500e-03
# Epoch 1600 : Loss=3.9675e-03
# Epoch 1600 : Loss=3.5002e-03
# Epoch 1600 : Loss=3.6305e-03
# Epoch 1600 : Loss=3.5645e-03
# Epoch 1600 : Loss=3.0020e-03
# Epoch 1600 : Loss=3.4372e-03
# Epoch 1600 : Loss=2.7208e-03
# Epoch 1600 : Loss=3.8816e-03
# Epoch 1600 : Loss=3.3018e-03
# Epoch 1600 : Loss=3.8913e-03
# Epoch 1600 : Loss=4.1631e-03
# Epoch 1600 : Loss=4.4529e-03
# Epoch 1600 : Loss=2.6167e-03
# Epoch 1600 : Loss=2.8376e-03
# Epoch 1600 : Loss=3.2194e-03
# Epoch 1600 : Loss=2.7968e-03
# Epoch 1600 : Loss=3.2162e-03
# Epoch 1600 : Loss=2.2505e-03
# Epoch 1600 : Loss=3.0302e-03
# Epoch 1600 : Loss=3.6821e-03
# Epoch 1600 : Loss=3.4239e-03
# Epoch 1800 : Loss=3.2460e-03
# Epoch 1800 : Loss=3.7395e-03
# Epoch 1800 : Loss=2.7124e-03
# Epoch 1800 : Loss=4.6364e-03
# Epoch 1800 : Loss=3.6182e-03
# Epoch 1800 : Loss=3.0911e-03
# Epoch 1800 : Loss=4.7091e-03
# Epoch 1800 : Loss=4.8789e-03
# Epoch 1800 : Loss=3.5077e-03
# Epoch 1800 : Loss=3.0336e-03
# Epoch 1800 : Loss=4.8080e-03
# Epoch 1800 : Loss=4.6016e-03
# Epoch 1800 : Loss=3.6646e-03
# Epoch 1800 : Loss=3.7322e-03
# Epoch 1800 : Loss=3.0277e-03
# Epoch 1800 : Loss=2.9979e-03
# Epoch 1800 : Loss=3.1961e-03
# Epoch 1800 : Loss=3.8919e-03
# Epoch 1800 : Loss=3.6136e-03
# Epoch 1800 : Loss=2.9793e-03
# Epoch 1800 : Loss=3.0927e-03
# Epoch 1800 : Loss=3.1370e-03
# Epoch 1800 : Loss=2.8640e-03
# Epoch 1800 : Loss=3.8383e-03
# Epoch 1800 : Loss=3.2918e-03
# Epoch 1800 : Loss=3.8481e-03
# Epoch 1800 : Loss=3.2753e-03
# Epoch 1800 : Loss=3.5234e-03
# Epoch 1800 : Loss=4.1250e-03
# Epoch 1800 : Loss=2.2433e-03
# Epoch 1800 : Loss=3.8496e-03
# Epoch 1800 : Loss=3.1277e-03
# Epoch 1800 : Loss=3.4764e-03
# Epoch 1800 : Loss=4.0573e-03
# Epoch 1800 : Loss=3.6361e-03
# Epoch 1800 : Loss=3.5585e-03
# Epoch 1800 : Loss=3.5795e-03
# Epoch 1800 : Loss=2.7073e-03
# Epoch 1800 : Loss=3.4148e-03
# Epoch 1800 : Loss=3.4409e-03
# Epoch 1800 : Loss=3.7279e-03
# Epoch 1800 : Loss=2.9328e-03
# Epoch 1800 : Loss=3.5203e-03
# Epoch 1800 : Loss=3.1380e-03
# Epoch 1800 : Loss=3.4979e-03
# Epoch 1800 : Loss=3.0795e-03
# Epoch 1800 : Loss=4.1792e-03
# Epoch 1800 : Loss=4.4333e-03
# Epoch 1800 : Loss=3.1431e-03
# Epoch 1800 : Loss=2.4663e-03
# Epoch 1800 : Loss=4.0421e-03
# Epoch 1800 : Loss=3.2072e-03
# Epoch 1800 : Loss=3.5238e-03
# Epoch 1800 : Loss=2.8393e-03
# Epoch 1800 : Loss=3.3956e-03
# Epoch 1800 : Loss=3.5096e-03
# Epoch 1800 : Loss=2.9194e-03
# Epoch 1800 : Loss=3.2880e-03
# Epoch 1800 : Loss=2.7825e-03
# Epoch 1800 : Loss=3.6292e-03
# Epoch 1800 : Loss=3.6427e-03
# Epoch 1800 : Loss=3.4201e-03
# Epoch 1800 : Loss=2.6360e-03
# Epoch 1800 : Loss=3.0258e-03
# Epoch 1800 : Loss=3.4412e-03
# Epoch 1800 : Loss=3.1895e-03
# Epoch 1800 : Loss=3.4238e-03
# Epoch 1800 : Loss=4.0900e-03
# Epoch 1800 : Loss=3.9146e-03
# Epoch 1800 : Loss=2.9129e-03
# Epoch 1800 : Loss=3.0548e-03
# Epoch 1800 : Loss=3.2543e-03
# Epoch 1800 : Loss=3.7101e-03
# Epoch 1800 : Loss=3.6427e-03
# Epoch 1800 : Loss=3.6743e-03
# Epoch 1800 : Loss=3.4803e-03
# Epoch 1800 : Loss=3.4425e-03
# Epoch 1800 : Loss=3.2738e-03
# Epoch 1800 : Loss=3.9776e-03
# Epoch 1800 : Loss=4.6121e-03
# Epoch 1800 : Loss=2.7390e-03
# Epoch 2000 : Loss=3.7050e-03
# Epoch 2000 : Loss=3.4951e-03
# Epoch 2000 : Loss=3.6053e-03
# Epoch 2000 : Loss=3.0842e-03
# Epoch 2000 : Loss=3.6962e-03
# Epoch 2000 : Loss=2.7627e-03
# Epoch 2000 : Loss=3.2913e-03
# Epoch 2000 : Loss=3.2625e-03
# Epoch 2000 : Loss=2.3038e-03
# Epoch 2000 : Loss=3.0893e-03
# Epoch 2000 : Loss=3.4387e-03
# Epoch 2000 : Loss=3.4373e-03
# Epoch 2000 : Loss=3.1366e-03
# Epoch 2000 : Loss=4.6175e-03
# Epoch 2000 : Loss=3.1465e-03
# Epoch 2000 : Loss=3.7158e-03
# Epoch 2000 : Loss=3.4842e-03
# Epoch 2000 : Loss=4.4301e-03
# Epoch 2000 : Loss=4.1505e-03
# Epoch 2000 : Loss=2.6163e-03
# Epoch 2000 : Loss=2.9878e-03
# Epoch 2000 : Loss=3.4847e-03
# Epoch 2000 : Loss=3.3464e-03
# Epoch 2000 : Loss=3.9769e-03
# Epoch 2000 : Loss=3.4342e-03
# Epoch 2000 : Loss=3.3414e-03
# Epoch 2000 : Loss=3.9331e-03
# Epoch 2000 : Loss=3.1112e-03
# Epoch 2000 : Loss=4.5360e-03
# Epoch 2000 : Loss=3.3336e-03
# Epoch 2000 : Loss=3.2058e-03
# Epoch 2000 : Loss=2.9175e-03
# Epoch 2000 : Loss=4.2627e-03
# Epoch 2000 : Loss=3.6801e-03
# Epoch 2000 : Loss=3.5931e-03
# Epoch 2000 : Loss=3.6735e-03
# Epoch 2000 : Loss=3.3315e-03
# Epoch 2000 : Loss=3.6294e-03
# Epoch 2000 : Loss=3.1968e-03
# Epoch 2000 : Loss=4.4638e-03
# Epoch 2000 : Loss=4.6645e-03
# Epoch 2000 : Loss=3.8753e-03
# Epoch 2000 : Loss=2.5423e-03
# Epoch 2000 : Loss=3.4644e-03
# Epoch 2000 : Loss=2.7923e-03
# Epoch 2000 : Loss=4.0820e-03
# Epoch 2000 : Loss=3.4025e-03
# Epoch 2000 : Loss=3.9131e-03
# Epoch 2000 : Loss=3.2162e-03
# Epoch 2000 : Loss=3.0118e-03
# Epoch 2000 : Loss=3.2089e-03
# Epoch 2000 : Loss=3.6671e-03
# Epoch 2000 : Loss=2.9246e-03
# Epoch 2000 : Loss=3.4487e-03
# Epoch 2000 : Loss=4.1021e-03
# Epoch 2000 : Loss=3.4548e-03
# Epoch 2000 : Loss=2.9171e-03
# Epoch 2000 : Loss=5.2113e-03
# Epoch 2000 : Loss=2.8819e-03
# Epoch 2000 : Loss=3.9996e-03
# Epoch 2000 : Loss=3.0438e-03
# Epoch 2000 : Loss=3.5992e-03
# Epoch 2000 : Loss=2.6855e-03
# Epoch 2000 : Loss=3.5529e-03
# Epoch 2000 : Loss=3.4201e-03
# Epoch 2000 : Loss=3.1705e-03
# Epoch 2000 : Loss=3.1273e-03
# Epoch 2000 : Loss=2.4176e-03
# Epoch 2000 : Loss=2.5722e-03
# Epoch 2000 : Loss=3.7745e-03
# Epoch 2000 : Loss=3.0323e-03
# Epoch 2000 : Loss=3.2304e-03
# Epoch 2000 : Loss=2.3298e-03
# Epoch 2000 : Loss=2.9213e-03
# Epoch 2000 : Loss=3.7923e-03
# Epoch 2000 : Loss=3.9553e-03
# Epoch 2000 : Loss=3.1304e-03
# Epoch 2000 : Loss=3.4717e-03
# Epoch 2000 : Loss=4.2907e-03
# Epoch 2000 : Loss=4.1090e-03
# Epoch 2000 : Loss=2.5017e-03
# Epoch 2200 : Loss=3.3927e-03
# Epoch 2200 : Loss=3.4762e-03
# Epoch 2200 : Loss=4.1830e-03
# Epoch 2200 : Loss=3.6241e-03
# Epoch 2200 : Loss=3.6006e-03
# Epoch 2200 : Loss=3.9263e-03
# Epoch 2200 : Loss=2.7563e-03
# Epoch 2200 : Loss=2.6536e-03
# Epoch 2200 : Loss=3.5551e-03
# Epoch 2200 : Loss=2.7993e-03
# Epoch 2200 : Loss=4.0713e-03
# Epoch 2200 : Loss=4.0890e-03
# Epoch 2200 : Loss=3.2292e-03
# Epoch 2200 : Loss=3.5749e-03
# Epoch 2200 : Loss=3.4079e-03
# Epoch 2200 : Loss=2.5927e-03
# Epoch 2200 : Loss=3.1568e-03
# Epoch 2200 : Loss=3.8304e-03
# Epoch 2200 : Loss=3.8126e-03
# Epoch 2200 : Loss=3.9642e-03
# Epoch 2200 : Loss=4.5773e-03
# Epoch 2200 : Loss=2.8084e-03
# Epoch 2200 : Loss=3.0298e-03
# Epoch 2200 : Loss=3.6301e-03
# Epoch 2200 : Loss=3.9452e-03
# Epoch 2200 : Loss=3.3500e-03
# Epoch 2200 : Loss=2.9667e-03
# Epoch 2200 : Loss=3.7608e-03
# Epoch 2200 : Loss=3.5686e-03
# Epoch 2200 : Loss=2.9001e-03
# Epoch 2200 : Loss=4.1762e-03
# Epoch 2200 : Loss=3.0045e-03
# Epoch 2200 : Loss=4.0537e-03
# Epoch 2200 : Loss=2.8486e-03
# Epoch 2200 : Loss=4.1949e-03
# Epoch 2200 : Loss=2.6130e-03
# Epoch 2200 : Loss=2.9596e-03
# Epoch 2200 : Loss=3.5942e-03
# Epoch 2200 : Loss=3.6759e-03
# Epoch 2200 : Loss=3.0608e-03
# Epoch 2200 : Loss=2.7529e-03
# Epoch 2200 : Loss=2.6443e-03
# Epoch 2200 : Loss=3.1721e-03
# Epoch 2200 : Loss=3.4500e-03
# Epoch 2200 : Loss=3.6921e-03
# Epoch 2200 : Loss=3.1372e-03
# Epoch 2200 : Loss=2.8545e-03
# Epoch 2200 : Loss=4.0951e-03
# Epoch 2200 : Loss=3.8331e-03
# Epoch 2200 : Loss=3.8214e-03
# Epoch 2200 : Loss=3.4098e-03
# Epoch 2200 : Loss=4.1236e-03
# Epoch 2200 : Loss=2.8307e-03
# Epoch 2200 : Loss=3.3186e-03
# Epoch 2200 : Loss=2.2558e-03
# Epoch 2200 : Loss=2.6812e-03
# Epoch 2200 : Loss=4.2321e-03
# Epoch 2200 : Loss=3.5148e-03
# Epoch 2200 : Loss=4.1446e-03
# Epoch 2200 : Loss=3.1280e-03
# Epoch 2200 : Loss=3.3426e-03
# Epoch 2200 : Loss=3.0610e-03
# Epoch 2200 : Loss=4.4586e-03
# Epoch 2200 : Loss=3.9168e-03
# Epoch 2200 : Loss=2.4543e-03
# Epoch 2200 : Loss=3.7307e-03
# Epoch 2200 : Loss=3.7001e-03
# Epoch 2200 : Loss=3.6756e-03
# Epoch 2200 : Loss=2.8067e-03
# Epoch 2200 : Loss=2.8918e-03
# Epoch 2200 : Loss=3.5095e-03
# Epoch 2200 : Loss=2.9250e-03
# Epoch 2200 : Loss=3.3000e-03
# Epoch 2200 : Loss=3.0702e-03
# Epoch 2200 : Loss=3.2064e-03
# Epoch 2200 : Loss=3.6981e-03
# Epoch 2200 : Loss=3.7235e-03
# Epoch 2200 : Loss=2.5798e-03
# Epoch 2200 : Loss=3.9436e-03
# Epoch 2200 : Loss=4.4956e-03
# Epoch 2200 : Loss=3.7611e-03
# Epoch 2400 : Loss=4.4766e-03
# Epoch 2400 : Loss=3.2190e-03
# Epoch 2400 : Loss=3.3906e-03
# Epoch 2400 : Loss=2.5424e-03
# Epoch 2400 : Loss=3.6244e-03
# Epoch 2400 : Loss=3.8442e-03
# Epoch 2400 : Loss=4.1021e-03
# Epoch 2400 : Loss=3.0800e-03
# Epoch 2400 : Loss=3.7104e-03
# Epoch 2400 : Loss=4.6733e-03
# Epoch 2400 : Loss=3.3424e-03
# Epoch 2400 : Loss=2.4652e-03
# Epoch 2400 : Loss=3.9825e-03
# Epoch 2400 : Loss=3.2766e-03
# Epoch 2400 : Loss=3.4332e-03
# Epoch 2400 : Loss=3.6492e-03
# Epoch 2400 : Loss=2.6669e-03
# Epoch 2400 : Loss=3.4433e-03
# Epoch 2400 : Loss=3.0150e-03
# Epoch 2400 : Loss=3.3255e-03
# Epoch 2400 : Loss=4.4813e-03
# Epoch 2400 : Loss=3.1051e-03
# Epoch 2400 : Loss=3.3066e-03
# Epoch 2400 : Loss=3.7884e-03
# Epoch 2400 : Loss=2.7674e-03
# Epoch 2400 : Loss=3.0451e-03
# Epoch 2400 : Loss=2.3491e-03
# Epoch 2400 : Loss=3.1237e-03
# Epoch 2400 : Loss=3.8307e-03
# Epoch 2400 : Loss=3.5070e-03
# Epoch 2400 : Loss=3.6853e-03
# Epoch 2400 : Loss=4.4608e-03
# Epoch 2400 : Loss=4.3451e-03
# Epoch 2400 : Loss=3.1372e-03
# Epoch 2400 : Loss=3.1336e-03
# Epoch 2400 : Loss=2.3446e-03
# Epoch 2400 : Loss=3.3149e-03
# Epoch 2400 : Loss=3.0041e-03
# Epoch 2400 : Loss=2.6385e-03
# Epoch 2400 : Loss=2.2725e-03
# Epoch 2400 : Loss=3.8376e-03
# Epoch 2400 : Loss=3.6402e-03
# Epoch 2400 : Loss=3.2841e-03
# Epoch 2400 : Loss=3.2689e-03
# Epoch 2400 : Loss=3.1306e-03
# Epoch 2400 : Loss=2.8323e-03
# Epoch 2400 : Loss=4.3214e-03
# Epoch 2400 : Loss=4.0328e-03
# Epoch 2400 : Loss=3.8354e-03
# Epoch 2400 : Loss=3.1710e-03
# Epoch 2400 : Loss=2.9222e-03
# Epoch 2400 : Loss=4.1963e-03
# Epoch 2400 : Loss=3.1827e-03
# Epoch 2400 : Loss=4.3743e-03
# Epoch 2400 : Loss=3.8925e-03
# Epoch 2400 : Loss=4.1913e-03
# Epoch 2400 : Loss=3.6023e-03
# Epoch 2400 : Loss=2.4627e-03
# Epoch 2400 : Loss=2.5462e-03
# Epoch 2400 : Loss=2.2883e-03
# Epoch 2400 : Loss=3.4875e-03
# Epoch 2400 : Loss=3.9173e-03
# Epoch 2400 : Loss=3.8310e-03
# Epoch 2400 : Loss=3.4771e-03
# Epoch 2400 : Loss=3.5482e-03
# Epoch 2400 : Loss=3.3756e-03
# Epoch 2400 : Loss=3.1051e-03
# Epoch 2400 : Loss=2.9655e-03
# Epoch 2400 : Loss=4.1029e-03
# Epoch 2400 : Loss=4.0766e-03
# Epoch 2400 : Loss=3.0268e-03
# Epoch 2400 : Loss=3.4195e-03
# Epoch 2400 : Loss=3.4146e-03
# Epoch 2400 : Loss=3.7971e-03
# Epoch 2400 : Loss=2.6779e-03
# Epoch 2400 : Loss=3.3614e-03
# Epoch 2400 : Loss=4.2777e-03
# Epoch 2400 : Loss=3.2452e-03
# Epoch 2400 : Loss=2.6977e-03
# Epoch 2400 : Loss=4.2661e-03
# Epoch 2400 : Loss=3.3840e-03
# Epoch 2600 : Loss=4.6170e-03
# Epoch 2600 : Loss=3.2297e-03
# Epoch 2600 : Loss=3.8220e-03
# Epoch 2600 : Loss=2.7099e-03
# Epoch 2600 : Loss=3.7510e-03
# Epoch 2600 : Loss=3.6609e-03
# Epoch 2600 : Loss=3.6339e-03
# Epoch 2600 : Loss=3.1287e-03
# Epoch 2600 : Loss=3.3977e-03
# Epoch 2600 : Loss=2.8890e-03
# Epoch 2600 : Loss=2.9050e-03
# Epoch 2600 : Loss=2.7323e-03
# Epoch 2600 : Loss=3.2924e-03
# Epoch 2600 : Loss=2.5669e-03
# Epoch 2600 : Loss=3.7374e-03
# Epoch 2600 : Loss=3.3533e-03
# Epoch 2600 : Loss=3.3824e-03
# Epoch 2600 : Loss=2.5905e-03
# Epoch 2600 : Loss=3.8086e-03
# Epoch 2600 : Loss=2.9698e-03
# Epoch 2600 : Loss=3.6820e-03
# Epoch 2600 : Loss=3.3067e-03
# Epoch 2600 : Loss=2.7284e-03
# Epoch 2600 : Loss=3.3647e-03
# Epoch 2600 : Loss=2.3115e-03
# Epoch 2600 : Loss=3.9455e-03
# Epoch 2600 : Loss=3.0530e-03
# Epoch 2600 : Loss=3.3508e-03
# Epoch 2600 : Loss=3.4423e-03
# Epoch 2600 : Loss=3.7317e-03
# Epoch 2600 : Loss=4.4104e-03
# Epoch 2600 : Loss=3.2386e-03
# Epoch 2600 : Loss=2.8892e-03
# Epoch 2600 : Loss=2.9435e-03
# Epoch 2600 : Loss=3.1246e-03
# Epoch 2600 : Loss=4.4421e-03
# Epoch 2600 : Loss=3.9568e-03
# Epoch 2600 : Loss=3.9728e-03
# Epoch 2600 : Loss=3.5791e-03
# Epoch 2600 : Loss=3.3125e-03
# Epoch 2600 : Loss=3.6390e-03
# Epoch 2600 : Loss=3.1713e-03
# Epoch 2600 : Loss=3.9294e-03
# Epoch 2600 : Loss=3.5520e-03
# Epoch 2600 : Loss=3.3474e-03
# Epoch 2600 : Loss=3.1297e-03
# Epoch 2600 : Loss=3.8215e-03
# Epoch 2600 : Loss=5.1769e-03
# Epoch 2600 : Loss=4.1302e-03
# Epoch 2600 : Loss=4.0973e-03
# Epoch 2600 : Loss=3.6570e-03
# Epoch 2600 : Loss=3.5200e-03
# Epoch 2600 : Loss=3.8111e-03
# Epoch 2600 : Loss=3.6083e-03
# Epoch 2600 : Loss=3.8602e-03
# Epoch 2600 : Loss=3.6567e-03
# Epoch 2600 : Loss=2.2054e-03
# Epoch 2600 : Loss=3.0148e-03
# Epoch 2600 : Loss=3.0256e-03
# Epoch 2600 : Loss=3.2571e-03
# Epoch 2600 : Loss=3.3155e-03
# Epoch 2600 : Loss=2.5835e-03
# Epoch 2600 : Loss=2.9172e-03
# Epoch 2600 : Loss=3.5743e-03
# Epoch 2600 : Loss=3.0327e-03
# Epoch 2600 : Loss=4.0503e-03
# Epoch 2600 : Loss=4.3644e-03
# Epoch 2600 : Loss=4.1457e-03
# Epoch 2600 : Loss=3.7061e-03
# Epoch 2600 : Loss=2.9376e-03
# Epoch 2600 : Loss=3.7159e-03
# Epoch 2600 : Loss=3.4437e-03
# Epoch 2600 : Loss=3.7595e-03
# Epoch 2600 : Loss=3.9128e-03
# Epoch 2600 : Loss=2.5592e-03
# Epoch 2600 : Loss=3.7304e-03
# Epoch 2600 : Loss=2.7740e-03
# Epoch 2600 : Loss=2.9645e-03
# Epoch 2600 : Loss=2.5729e-03
# Epoch 2600 : Loss=3.3135e-03
# Epoch 2600 : Loss=3.6430e-03
# Epoch 2800 : Loss=2.8000e-03
# Epoch 2800 : Loss=3.6634e-03
# Epoch 2800 : Loss=2.9969e-03
# Epoch 2800 : Loss=3.3285e-03
# Epoch 2800 : Loss=3.7332e-03
# Epoch 2800 : Loss=2.6342e-03
# Epoch 2800 : Loss=2.9310e-03
# Epoch 2800 : Loss=3.9974e-03
# Epoch 2800 : Loss=2.7683e-03
# Epoch 2800 : Loss=3.0890e-03
# Epoch 2800 : Loss=2.4768e-03
# Epoch 2800 : Loss=3.7832e-03
# Epoch 2800 : Loss=4.0221e-03
# Epoch 2800 : Loss=4.2573e-03
# Epoch 2800 : Loss=3.7761e-03
# Epoch 2800 : Loss=6.4649e-03
# Epoch 2800 : Loss=2.6988e-03
# Epoch 2800 : Loss=3.4373e-03
# Epoch 2800 : Loss=3.7776e-03
# Epoch 2800 : Loss=3.5430e-03
# Epoch 2800 : Loss=4.2854e-03
# Epoch 2800 : Loss=3.1611e-03
# Epoch 2800 : Loss=3.6686e-03
# Epoch 2800 : Loss=3.0410e-03
# Epoch 2800 : Loss=4.0455e-03
# Epoch 2800 : Loss=3.2458e-03
# Epoch 2800 : Loss=3.6931e-03
# Epoch 2800 : Loss=2.9823e-03
# Epoch 2800 : Loss=3.4072e-03
# Epoch 2800 : Loss=4.0060e-03
# Epoch 2800 : Loss=3.0664e-03
# Epoch 2800 : Loss=3.3368e-03
# Epoch 2800 : Loss=4.3505e-03
# Epoch 2800 : Loss=2.7971e-03
# Epoch 2800 : Loss=2.8748e-03
# Epoch 2800 : Loss=2.7237e-03
# Epoch 2800 : Loss=5.2060e-03
# Epoch 2800 : Loss=3.5642e-03
# Epoch 2800 : Loss=4.0464e-03
# Epoch 2800 : Loss=4.5343e-03
# Epoch 2800 : Loss=3.9153e-03
# Epoch 2800 : Loss=3.5859e-03
# Epoch 2800 : Loss=4.3119e-03
# Epoch 2800 : Loss=3.8899e-03
# Epoch 2800 : Loss=3.1407e-03
# Epoch 2800 : Loss=3.0518e-03
# Epoch 2800 : Loss=4.1594e-03
# Epoch 2800 : Loss=2.9355e-03
# Epoch 2800 : Loss=2.4429e-03
# Epoch 2800 : Loss=3.9207e-03
# Epoch 2800 : Loss=3.9173e-03
# Epoch 2800 : Loss=3.5595e-03
# Epoch 2800 : Loss=3.9998e-03
# Epoch 2800 : Loss=3.0360e-03
# Epoch 2800 : Loss=3.0573e-03
# Epoch 2800 : Loss=3.1122e-03
# Epoch 2800 : Loss=3.5156e-03
# Epoch 2800 : Loss=3.0541e-03
# Epoch 2800 : Loss=2.8971e-03
# Epoch 2800 : Loss=3.2631e-03
# Epoch 2800 : Loss=4.3973e-03
# Epoch 2800 : Loss=3.3741e-03
# Epoch 2800 : Loss=3.2125e-03
# Epoch 2800 : Loss=3.5023e-03
# Epoch 2800 : Loss=2.7391e-03
# Epoch 2800 : Loss=2.5340e-03
# Epoch 2800 : Loss=2.8246e-03
# Epoch 2800 : Loss=3.2494e-03
# Epoch 2800 : Loss=3.4509e-03
# Epoch 2800 : Loss=3.2083e-03
# Epoch 2800 : Loss=3.4934e-03
# Epoch 2800 : Loss=4.0697e-03
# Epoch 2800 : Loss=3.5531e-03
# Epoch 2800 : Loss=3.0446e-03
# Epoch 2800 : Loss=3.4731e-03
# Epoch 2800 : Loss=2.8469e-03
# Epoch 2800 : Loss=3.6211e-03
# Epoch 2800 : Loss=2.9213e-03
# Epoch 2800 : Loss=3.4552e-03
# Epoch 2800 : Loss=3.2725e-03
# Epoch 2800 : Loss=3.8970e-03
# Epoch 3000 : Loss=3.0338e-03
# Epoch 3000 : Loss=4.9044e-03
# Epoch 3000 : Loss=4.0235e-03
# Epoch 3000 : Loss=3.1889e-03
# Epoch 3000 : Loss=2.5458e-03
# Epoch 3000 : Loss=3.2556e-03
# Epoch 3000 : Loss=2.8480e-03
# Epoch 3000 : Loss=2.8509e-03
# Epoch 3000 : Loss=3.7938e-03
# Epoch 3000 : Loss=2.8538e-03
# Epoch 3000 : Loss=3.4860e-03
# Epoch 3000 : Loss=4.4936e-03
# Epoch 3000 : Loss=3.7063e-03
# Epoch 3000 : Loss=3.3331e-03
# Epoch 3000 : Loss=3.4651e-03
# Epoch 3000 : Loss=3.8091e-03
# Epoch 3000 : Loss=3.1522e-03
# Epoch 3000 : Loss=2.9003e-03
# Epoch 3000 : Loss=4.6575e-03
# Epoch 3000 : Loss=3.6294e-03
# Epoch 3000 : Loss=3.2130e-03
# Epoch 3000 : Loss=4.0603e-03
# Epoch 3000 : Loss=3.3159e-03
# Epoch 3000 : Loss=3.1879e-03
# Epoch 3000 : Loss=2.7241e-03
# Epoch 3000 : Loss=3.3144e-03
# Epoch 3000 : Loss=3.7373e-03
# Epoch 3000 : Loss=4.2345e-03
# Epoch 3000 : Loss=3.1101e-03
# Epoch 3000 : Loss=3.7786e-03
# Epoch 3000 : Loss=2.8605e-03
# Epoch 3000 : Loss=3.3851e-03
# Epoch 3000 : Loss=3.2565e-03
# Epoch 3000 : Loss=3.1750e-03
# Epoch 3000 : Loss=3.3211e-03
# Epoch 3000 : Loss=3.1344e-03
# Epoch 3000 : Loss=2.6714e-03
# Epoch 3000 : Loss=3.7719e-03
# Epoch 3000 : Loss=2.9985e-03
# Epoch 3000 : Loss=3.8880e-03
# Epoch 3000 : Loss=4.2288e-03
# Epoch 3000 : Loss=5.0336e-03
# Epoch 3000 : Loss=4.8982e-03
# Epoch 3000 : Loss=3.2626e-03
# Epoch 3000 : Loss=2.3824e-03
# Epoch 3000 : Loss=2.8883e-03
# Epoch 3000 : Loss=2.8750e-03
# Epoch 3000 : Loss=3.6684e-03
# Epoch 3000 : Loss=4.2787e-03
# Epoch 3000 : Loss=3.3968e-03
# Epoch 3000 : Loss=2.9903e-03
# Epoch 3000 : Loss=3.1515e-03
# Epoch 3000 : Loss=3.5857e-03
# Epoch 3000 : Loss=3.1690e-03
# Epoch 3000 : Loss=2.4101e-03
# Epoch 3000 : Loss=3.2610e-03
# Epoch 3000 : Loss=2.3990e-03
# Epoch 3000 : Loss=3.6322e-03
# Epoch 3000 : Loss=4.4497e-03
# Epoch 3000 : Loss=3.4106e-03
# Epoch 3000 : Loss=4.3348e-03
# Epoch 3000 : Loss=3.3311e-03
# Epoch 3000 : Loss=2.9960e-03
# Epoch 3000 : Loss=3.1583e-03
# Epoch 3000 : Loss=2.8243e-03
# Epoch 3000 : Loss=4.1118e-03
# Epoch 3000 : Loss=2.9228e-03
# Epoch 3000 : Loss=2.8433e-03
# Epoch 3000 : Loss=3.2536e-03
# Epoch 3000 : Loss=3.6790e-03
# Epoch 3000 : Loss=3.2932e-03
# Epoch 3000 : Loss=2.8785e-03
# Epoch 3000 : Loss=3.1292e-03
# Epoch 3000 : Loss=2.8461e-03
# Epoch 3000 : Loss=3.3048e-03
# Epoch 3000 : Loss=5.2877e-03
# Epoch 3000 : Loss=2.9019e-03
# Epoch 3000 : Loss=2.8449e-03
# Epoch 3000 : Loss=2.6864e-03
# Epoch 3000 : Loss=2.9984e-03
# Epoch 3000 : Loss=3.5362e-03
# Epoch 3200 : Loss=2.7001e-03
# Epoch 3200 : Loss=4.2258e-03
# Epoch 3200 : Loss=3.1968e-03
# Epoch 3200 : Loss=3.1104e-03
# Epoch 3200 : Loss=3.6915e-03
# Epoch 3200 : Loss=2.6979e-03
# Epoch 3200 : Loss=3.0980e-03
# Epoch 3200 : Loss=3.7075e-03
# Epoch 3200 : Loss=3.8580e-03
# Epoch 3200 : Loss=3.1470e-03
# Epoch 3200 : Loss=3.7361e-03
# Epoch 3200 : Loss=3.9792e-03
# Epoch 3200 : Loss=4.6350e-03
# Epoch 3200 : Loss=3.4566e-03
# Epoch 3200 : Loss=3.0355e-03
# Epoch 3200 : Loss=2.6208e-03
# Epoch 3200 : Loss=3.1508e-03
# Epoch 3200 : Loss=3.8384e-03
# Epoch 3200 : Loss=2.7522e-03
# Epoch 3200 : Loss=2.6640e-03
# Epoch 3200 : Loss=2.8990e-03
# Epoch 3200 : Loss=4.1478e-03
# Epoch 3200 : Loss=3.5025e-03
# Epoch 3200 : Loss=4.0126e-03
# Epoch 3200 : Loss=2.9646e-03
# Epoch 3200 : Loss=3.7514e-03
# Epoch 3200 : Loss=3.5193e-03
# Epoch 3200 : Loss=3.7134e-03
# Epoch 3200 : Loss=3.3199e-03
# Epoch 3200 : Loss=3.3592e-03
# Epoch 3200 : Loss=3.7148e-03
# Epoch 3200 : Loss=3.3254e-03
# Epoch 3200 : Loss=4.5659e-03
# Epoch 3200 : Loss=2.4160e-03
# Epoch 3200 : Loss=3.3965e-03
# Epoch 3200 : Loss=3.7005e-03
# Epoch 3200 : Loss=3.2182e-03
# Epoch 3200 : Loss=2.6801e-03
# Epoch 3200 : Loss=2.5167e-03
# Epoch 3200 : Loss=3.9124e-03
# Epoch 3200 : Loss=2.9631e-03
# Epoch 3200 : Loss=2.5076e-03
# Epoch 3200 : Loss=3.0578e-03
# Epoch 3200 : Loss=3.4616e-03
# Epoch 3200 : Loss=2.8859e-03
# Epoch 3200 : Loss=4.0802e-03
# Epoch 3200 : Loss=3.4395e-03
# Epoch 3200 : Loss=3.1795e-03
# Epoch 3200 : Loss=3.2221e-03
# Epoch 3200 : Loss=3.5219e-03
# Epoch 3200 : Loss=3.3759e-03
# Epoch 3200 : Loss=3.5337e-03
# Epoch 3200 : Loss=2.2767e-03
# Epoch 3200 : Loss=5.0683e-03
# Epoch 3200 : Loss=3.2549e-03
# Epoch 3200 : Loss=2.3621e-03
# Epoch 3200 : Loss=2.7378e-03
# Epoch 3200 : Loss=3.0955e-03
# Epoch 3200 : Loss=3.3392e-03
# Epoch 3200 : Loss=3.1027e-03
# Epoch 3200 : Loss=4.7114e-03
# Epoch 3200 : Loss=5.1862e-03
# Epoch 3200 : Loss=2.7664e-03
# Epoch 3200 : Loss=3.5174e-03
# Epoch 3200 : Loss=3.7339e-03
# Epoch 3200 : Loss=4.1919e-03
# Epoch 3200 : Loss=4.1843e-03
# Epoch 3200 : Loss=3.9262e-03
# Epoch 3200 : Loss=3.1853e-03
# Epoch 3200 : Loss=3.5193e-03
# Epoch 3200 : Loss=3.3241e-03
# Epoch 3200 : Loss=4.8253e-03
# Epoch 3200 : Loss=3.4731e-03
# Epoch 3200 : Loss=3.3632e-03
# Epoch 3200 : Loss=2.7810e-03
# Epoch 3200 : Loss=2.5117e-03
# Epoch 3200 : Loss=3.7201e-03
# Epoch 3200 : Loss=3.4987e-03
# Epoch 3200 : Loss=3.1992e-03
# Epoch 3200 : Loss=2.1482e-03
# Epoch 3200 : Loss=3.7703e-03
# Epoch 3400 : Loss=2.7741e-03
# Epoch 3400 : Loss=4.1202e-03
# Epoch 3400 : Loss=2.8932e-03
# Epoch 3400 : Loss=3.5596e-03
# Epoch 3400 : Loss=2.6367e-03
# Epoch 3400 : Loss=2.9383e-03
# Epoch 3400 : Loss=3.2324e-03
# Epoch 3400 : Loss=3.2926e-03
# Epoch 3400 : Loss=3.6503e-03
# Epoch 3400 : Loss=3.1067e-03
# Epoch 3400 : Loss=3.1430e-03
# Epoch 3400 : Loss=3.5731e-03
# Epoch 3400 : Loss=2.8981e-03
# Epoch 3400 : Loss=3.0490e-03
# Epoch 3400 : Loss=2.7820e-03
# Epoch 3400 : Loss=2.7692e-03
# Epoch 3400 : Loss=3.7909e-03
# Epoch 3400 : Loss=2.8403e-03
# Epoch 3400 : Loss=2.4170e-03
# Epoch 3400 : Loss=3.0299e-03
# Epoch 3400 : Loss=3.7840e-03
# Epoch 3400 : Loss=4.1944e-03
# Epoch 3400 : Loss=3.1380e-03
# Epoch 3400 : Loss=3.9299e-03
# Epoch 3400 : Loss=3.3680e-03
# Epoch 3400 : Loss=4.5301e-03
# Epoch 3400 : Loss=2.7463e-03
# Epoch 3400 : Loss=3.5398e-03
# Epoch 3400 : Loss=4.1530e-03
# Epoch 3400 : Loss=2.9990e-03
# Epoch 3400 : Loss=3.7134e-03
# Epoch 3400 : Loss=4.1196e-03
# Epoch 3400 : Loss=3.3744e-03
# Epoch 3400 : Loss=3.8639e-03
# Epoch 3400 : Loss=3.0897e-03
# Epoch 3400 : Loss=3.9598e-03
# Epoch 3400 : Loss=4.2103e-03
# Epoch 3400 : Loss=3.8686e-03
# Epoch 3400 : Loss=4.6224e-03
# Epoch 3400 : Loss=3.3628e-03
# Epoch 3400 : Loss=4.9073e-03
# Epoch 3400 : Loss=3.8865e-03
# Epoch 3400 : Loss=3.4999e-03
# Epoch 3400 : Loss=3.2349e-03
# Epoch 3400 : Loss=2.8395e-03
# Epoch 3400 : Loss=3.0265e-03
# Epoch 3400 : Loss=3.5728e-03
# Epoch 3400 : Loss=3.5241e-03
# Epoch 3400 : Loss=3.0045e-03
# Epoch 3400 : Loss=2.6618e-03
# Epoch 3400 : Loss=2.7392e-03
# Epoch 3400 : Loss=2.6777e-03
# Epoch 3400 : Loss=3.2606e-03
# Epoch 3400 : Loss=2.8683e-03
# Epoch 3400 : Loss=3.2368e-03
# Epoch 3400 : Loss=3.0903e-03
# Epoch 3400 : Loss=3.3943e-03
# Epoch 3400 : Loss=3.2293e-03
# Epoch 3400 : Loss=3.2774e-03
# Epoch 3400 : Loss=4.0520e-03
# Epoch 3400 : Loss=2.7734e-03
# Epoch 3400 : Loss=3.3190e-03
# Epoch 3400 : Loss=3.0152e-03
# Epoch 3400 : Loss=3.4543e-03
# Epoch 3400 : Loss=4.0670e-03
# Epoch 3400 : Loss=4.2731e-03
# Epoch 3400 : Loss=3.9170e-03
# Epoch 3400 : Loss=2.7784e-03
# Epoch 3400 : Loss=3.1093e-03
# Epoch 3400 : Loss=3.1169e-03
# Epoch 3400 : Loss=3.7834e-03
# Epoch 3400 : Loss=4.2688e-03
# Epoch 3400 : Loss=2.8694e-03
# Epoch 3400 : Loss=2.9100e-03
# Epoch 3400 : Loss=4.4621e-03
# Epoch 3400 : Loss=3.3680e-03
# Epoch 3400 : Loss=3.2393e-03
# Epoch 3400 : Loss=3.7388e-03
# Epoch 3400 : Loss=3.6963e-03
# Epoch 3400 : Loss=2.6942e-03
# Epoch 3400 : Loss=2.9173e-03
# Epoch 3600 : Loss=3.8993e-03
# Epoch 3600 : Loss=2.3550e-03
# Epoch 3600 : Loss=2.2707e-03
# Epoch 3600 : Loss=3.5353e-03
# Epoch 3600 : Loss=2.9662e-03
# Epoch 3600 : Loss=3.0732e-03
# Epoch 3600 : Loss=3.1148e-03
# Epoch 3600 : Loss=2.8158e-03
# Epoch 3600 : Loss=4.1305e-03
# Epoch 3600 : Loss=3.9464e-03
# Epoch 3600 : Loss=3.5471e-03
# Epoch 3600 : Loss=4.0600e-03
# Epoch 3600 : Loss=2.4524e-03
# Epoch 3600 : Loss=3.3686e-03
# Epoch 3600 : Loss=3.5130e-03
# Epoch 3600 : Loss=2.8911e-03
# Epoch 3600 : Loss=4.1064e-03
# Epoch 3600 : Loss=2.8512e-03
# Epoch 3600 : Loss=3.6088e-03
# Epoch 3600 : Loss=3.4130e-03
# Epoch 3600 : Loss=2.6229e-03
# Epoch 3600 : Loss=2.9663e-03
# Epoch 3600 : Loss=4.0179e-03
# Epoch 3600 : Loss=3.7269e-03
# Epoch 3600 : Loss=3.2788e-03
# Epoch 3600 : Loss=2.5625e-03
# Epoch 3600 : Loss=2.7280e-03
# Epoch 3600 : Loss=3.1086e-03
# Epoch 3600 : Loss=3.6063e-03
# Epoch 3600 : Loss=3.9200e-03
# Epoch 3600 : Loss=2.6929e-03
# Epoch 3600 : Loss=4.1689e-03
# Epoch 3600 : Loss=3.5887e-03
# Epoch 3600 : Loss=2.3793e-03
# Epoch 3600 : Loss=2.9288e-03
# Epoch 3600 : Loss=2.6322e-03
# Epoch 3600 : Loss=4.1376e-03
# Epoch 3600 : Loss=3.6759e-03
# Epoch 3600 : Loss=3.5152e-03
# Epoch 3600 : Loss=3.8898e-03
# Epoch 3600 : Loss=2.9985e-03
# Epoch 3600 : Loss=2.9850e-03
# Epoch 3600 : Loss=5.0050e-03
# Epoch 3600 : Loss=3.1966e-03
# Epoch 3600 : Loss=3.7243e-03
# Epoch 3600 : Loss=2.6222e-03
# Epoch 3600 : Loss=3.2081e-03
# Epoch 3600 : Loss=3.0954e-03
# Epoch 3600 : Loss=2.3002e-03
# Epoch 3600 : Loss=3.3494e-03
# Epoch 3600 : Loss=3.4913e-03
# Epoch 3600 : Loss=3.3047e-03
# Epoch 3600 : Loss=3.0141e-03
# Epoch 3600 : Loss=4.1523e-03
# Epoch 3600 : Loss=4.6936e-03
# Epoch 3600 : Loss=4.2547e-03
# Epoch 3600 : Loss=3.0564e-03
# Epoch 3600 : Loss=4.0364e-03
# Epoch 3600 : Loss=2.7819e-03
# Epoch 3600 : Loss=2.7552e-03
# Epoch 3600 : Loss=3.3138e-03
# Epoch 3600 : Loss=3.5444e-03
# Epoch 3600 : Loss=2.8281e-03
# Epoch 3600 : Loss=4.1195e-03
# Epoch 3600 : Loss=5.0060e-03
# Epoch 3600 : Loss=3.3789e-03
# Epoch 3600 : Loss=2.8356e-03
# Epoch 3600 : Loss=2.8318e-03
# Epoch 3600 : Loss=5.1685e-03
# Epoch 3600 : Loss=3.4065e-03
# Epoch 3600 : Loss=3.0752e-03
# Epoch 3600 : Loss=3.9766e-03
# Epoch 3600 : Loss=3.5088e-03
# Epoch 3600 : Loss=4.0166e-03
# Epoch 3600 : Loss=2.7304e-03
# Epoch 3600 : Loss=3.1971e-03
# Epoch 3600 : Loss=4.4235e-03
# Epoch 3600 : Loss=3.8409e-03
# Epoch 3600 : Loss=3.5972e-03
# Epoch 3600 : Loss=2.4937e-03
# Epoch 3600 : Loss=3.3233e-03
# Epoch 3800 : Loss=3.2794e-03
# Epoch 3800 : Loss=3.1206e-03
# Epoch 3800 : Loss=2.5822e-03
# Epoch 3800 : Loss=3.3367e-03
# Epoch 3800 : Loss=2.8594e-03
# Epoch 3800 : Loss=3.8859e-03
# Epoch 3800 : Loss=3.5694e-03
# Epoch 3800 : Loss=3.5125e-03
# Epoch 3800 : Loss=3.7727e-03
# Epoch 3800 : Loss=3.5882e-03
# Epoch 3800 : Loss=2.7769e-03
# Epoch 3800 : Loss=2.8035e-03
# Epoch 3800 : Loss=3.0435e-03
# Epoch 3800 : Loss=2.9885e-03
# Epoch 3800 : Loss=3.3687e-03
# Epoch 3800 : Loss=2.8809e-03
# Epoch 3800 : Loss=4.5545e-03
# Epoch 3800 : Loss=3.6494e-03
# Epoch 3800 : Loss=3.1070e-03
# Epoch 3800 : Loss=2.8511e-03
# Epoch 3800 : Loss=3.0862e-03
# Epoch 3800 : Loss=3.9564e-03
# Epoch 3800 : Loss=4.7239e-03
# Epoch 3800 : Loss=4.6613e-03
# Epoch 3800 : Loss=2.6212e-03
# Epoch 3800 : Loss=4.2628e-03
# Epoch 3800 : Loss=2.8422e-03
# Epoch 3800 : Loss=4.1769e-03
# Epoch 3800 : Loss=4.0454e-03
# Epoch 3800 : Loss=2.8541e-03
# Epoch 3800 : Loss=3.6321e-03
# Epoch 3800 : Loss=3.4007e-03
# Epoch 3800 : Loss=2.3375e-03
# Epoch 3800 : Loss=3.6347e-03
# Epoch 3800 : Loss=3.1101e-03
# Epoch 3800 : Loss=3.7974e-03
# Epoch 3800 : Loss=3.8044e-03
# Epoch 3800 : Loss=3.1784e-03
# Epoch 3800 : Loss=3.5739e-03
# Epoch 3800 : Loss=4.3757e-03
# Epoch 3800 : Loss=3.3499e-03
# Epoch 3800 : Loss=3.9951e-03
# Epoch 3800 : Loss=3.6338e-03
# Epoch 3800 : Loss=2.9354e-03
# Epoch 3800 : Loss=3.6631e-03
# Epoch 3800 : Loss=3.5507e-03
# Epoch 3800 : Loss=3.1372e-03
# Epoch 3800 : Loss=3.7988e-03
# Epoch 3800 : Loss=3.3907e-03
# Epoch 3800 : Loss=3.9218e-03
# Epoch 3800 : Loss=2.5572e-03
# Epoch 3800 : Loss=2.4928e-03
# Epoch 3800 : Loss=2.5186e-03
# Epoch 3800 : Loss=3.3692e-03
# Epoch 3800 : Loss=4.0707e-03
# Epoch 3800 : Loss=3.3567e-03
# Epoch 3800 : Loss=3.8051e-03
# Epoch 3800 : Loss=3.7433e-03
# Epoch 3800 : Loss=3.6989e-03
# Epoch 3800 : Loss=3.8274e-03
# Epoch 3800 : Loss=3.2271e-03
# Epoch 3800 : Loss=2.9350e-03
# Epoch 3800 : Loss=2.8552e-03
# Epoch 3800 : Loss=1.8761e-03
# Epoch 3800 : Loss=3.8513e-03
# Epoch 3800 : Loss=3.4820e-03
# Epoch 3800 : Loss=3.2348e-03
# Epoch 3800 : Loss=3.7198e-03
# Epoch 3800 : Loss=4.0473e-03
# Epoch 3800 : Loss=2.7821e-03
# Epoch 3800 : Loss=4.0744e-03
# Epoch 3800 : Loss=4.5996e-03
# Epoch 3800 : Loss=2.7741e-03
# Epoch 3800 : Loss=2.6816e-03
# Epoch 3800 : Loss=3.0229e-03
# Epoch 3800 : Loss=3.6321e-03
# Epoch 3800 : Loss=2.8960e-03
# Epoch 3800 : Loss=2.8624e-03
# Epoch 3800 : Loss=3.3109e-03
# Epoch 3800 : Loss=2.8461e-03
# Epoch 3800 : Loss=2.9857e-03
# Epoch 4000 : Loss=3.1603e-03
# Epoch 4000 : Loss=3.2360e-03
# Epoch 4000 : Loss=2.8597e-03
# Epoch 4000 : Loss=3.5993e-03
# Epoch 4000 : Loss=3.9061e-03
# Epoch 4000 : Loss=3.3046e-03
# Epoch 4000 : Loss=3.3416e-03
# Epoch 4000 : Loss=3.1973e-03
# Epoch 4000 : Loss=3.0498e-03
# Epoch 4000 : Loss=4.3798e-03
# Epoch 4000 : Loss=4.1915e-03
# Epoch 4000 : Loss=3.2096e-03
# Epoch 4000 : Loss=3.7943e-03
# Epoch 4000 : Loss=2.7654e-03
# Epoch 4000 : Loss=3.5121e-03
# Epoch 4000 : Loss=4.4760e-03
# Epoch 4000 : Loss=3.1667e-03
# Epoch 4000 : Loss=3.9285e-03
# Epoch 4000 : Loss=4.1183e-03
# Epoch 4000 : Loss=3.6676e-03
# Epoch 4000 : Loss=3.4289e-03
# Epoch 4000 : Loss=2.9154e-03
# Epoch 4000 : Loss=4.1011e-03
# Epoch 4000 : Loss=3.8378e-03
# Epoch 4000 : Loss=3.6599e-03
# Epoch 4000 : Loss=3.5885e-03
# Epoch 4000 : Loss=4.3202e-03
# Epoch 4000 : Loss=3.4035e-03
# Epoch 4000 : Loss=3.8492e-03
# Epoch 4000 : Loss=3.4510e-03
# Epoch 4000 : Loss=3.7497e-03
# Epoch 4000 : Loss=2.6236e-03
# Epoch 4000 : Loss=3.6266e-03
# Epoch 4000 : Loss=2.8654e-03
# Epoch 4000 : Loss=3.0191e-03
# Epoch 4000 : Loss=2.4318e-03
# Epoch 4000 : Loss=3.1498e-03
# Epoch 4000 : Loss=2.9475e-03
# Epoch 4000 : Loss=3.4936e-03
# Epoch 4000 : Loss=3.4500e-03
# Epoch 4000 : Loss=4.5586e-03
# Epoch 4000 : Loss=3.2969e-03
# Epoch 4000 : Loss=4.1457e-03
# Epoch 4000 : Loss=3.5803e-03
# Epoch 4000 : Loss=2.4837e-03
# Epoch 4000 : Loss=3.3187e-03
# Epoch 4000 : Loss=2.9405e-03
# Epoch 4000 : Loss=2.8162e-03
# Epoch 4000 : Loss=2.8421e-03
# Epoch 4000 : Loss=3.2012e-03
# Epoch 4000 : Loss=3.3276e-03
# Epoch 4000 : Loss=3.3195e-03
# Epoch 4000 : Loss=2.6031e-03
# Epoch 4000 : Loss=3.2882e-03
# Epoch 4000 : Loss=3.9397e-03
# Epoch 4000 : Loss=3.2554e-03
# Epoch 4000 : Loss=3.3329e-03
# Epoch 4000 : Loss=2.9235e-03
# Epoch 4000 : Loss=2.8118e-03
# Epoch 4000 : Loss=2.7454e-03
# Epoch 4000 : Loss=3.6207e-03
# Epoch 4000 : Loss=3.2327e-03
# Epoch 4000 : Loss=2.4912e-03
# Epoch 4000 : Loss=2.7377e-03
# Epoch 4000 : Loss=3.8274e-03
# Epoch 4000 : Loss=3.3789e-03
# Epoch 4000 : Loss=3.7169e-03
# Epoch 4000 : Loss=3.2026e-03
# Epoch 4000 : Loss=5.8019e-03
# Epoch 4000 : Loss=3.2262e-03
# Epoch 4000 : Loss=3.2808e-03
# Epoch 4000 : Loss=3.5836e-03
# Epoch 4000 : Loss=2.5712e-03
# Epoch 4000 : Loss=3.3706e-03
# Epoch 4000 : Loss=3.2289e-03
# Epoch 4000 : Loss=3.4641e-03
# Epoch 4000 : Loss=3.9470e-03
# Epoch 4000 : Loss=2.9047e-03
# Epoch 4000 : Loss=3.9649e-03
# Epoch 4000 : Loss=3.2116e-03
# Epoch 4000 : Loss=3.7518e-03

# %% [markdown]
# ## 결과 확인

# %%
df = pd.DataFrame(torch.cat([y, y_hat], dim=1).detach().numpy(), columns=['y','y_hat'])
sns.pairplot(df, height=5)
plt.show()
